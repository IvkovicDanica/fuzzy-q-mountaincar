# %%
import gymnasium as gym
import numpy as np
from stable_baselines3 import DQN

env = gym.make("CartPole-v1")

model = DQN(
    "MlpPolicy",
    env,
    learning_rate=0.001,
    gamma=0.99,
    exploration_initial_eps=1.0,
    exploration_final_eps=0.01,
    verbose=1,
    seed=42,
)

def evaluate(model, n_episodes=100):
    rewards = []
    for _ in range(n_episodes):
        obs, _ = env.reset()
        done = False
        total_reward = 0
        while not done:
            action, _ = model.predict(obs, deterministic=True)
            obs, reward, terminated, truncated, _ = env.step(action)
            total_reward += reward
            done = terminated or truncated
        rewards.append(total_reward)
    return np.mean(rewards)

target_score = 475
timesteps_per_round = 10_000  
average_reward = 0

while average_reward < target_score:
    model.learn(total_timesteps=timesteps_per_round, reset_num_timesteps=False)
    average_reward = evaluate(model)
    print(f"Average reward over 100 episodes: {average_reward:.2f}")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23       |
# |    ep_rew_mean      | 23       |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 11501    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 92       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.6     |
# |    ep_rew_mean      | 27.6     |
# |    exploration_rate | 0.781    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1475     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 221      |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.116    |
# |    n_updates        | 30       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.5     |
# |    ep_rew_mean      | 26.5     |
# |    exploration_rate | 0.685    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1360     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 318      |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0092   |
# |    n_updates        | 54       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.4     |
# |    ep_rew_mean      | 25.4     |
# |    exploration_rate | 0.597    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1318     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 407      |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00381  |
# |    n_updates        | 76       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.4     |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.536    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1285     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 469      |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00308  |
# |    n_updates        | 92       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.485    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1275     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 520      |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00243  |
# |    n_updates        | 104      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.434    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1246     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 572      |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00083  |
# |    n_updates        | 117      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.357    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1227     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 650      |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000532 |
# |    n_updates        | 137      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.293    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1216     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 714      |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00052  |
# |    n_updates        | 153      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.3     |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.237    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1207     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 771      |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000266 |
# |    n_updates        | 167      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.7     |
# |    ep_rew_mean      | 18.7     |
# |    exploration_rate | 0.186    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1188     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 822      |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000121 |
# |    n_updates        | 180      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.4     |
# |    ep_rew_mean      | 18.4     |
# |    exploration_rate | 0.126    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1173     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 883      |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000177 |
# |    n_updates        | 195      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18       |
# |    ep_rew_mean      | 18       |
# |    exploration_rate | 0.0734   |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1164     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 936      |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000177 |
# |    n_updates        | 208      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.6     |
# |    ep_rew_mean      | 17.6     |
# |    exploration_rate | 0.0258   |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1152     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 984      |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000423 |
# |    n_updates        | 220      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.3     |
# |    ep_rew_mean      | 17.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1138     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1037     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000171 |
# |    n_updates        | 234      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17       |
# |    ep_rew_mean      | 17       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1132     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1086     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000265 |
# |    n_updates        | 246      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.7     |
# |    ep_rew_mean      | 16.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1127     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1138     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00013  |
# |    n_updates        | 259      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16
|
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2676     |
# |    fps              | 1146     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 121972   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.23     |
# |    n_updates        | 30467    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 140      |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2680     |
# |    fps              | 1150     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 122510   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00835  |
# |    n_updates        | 30602    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2684     |
# |    fps              | 1147     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 122977   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0171   |
# |    n_updates        | 30719    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2688     |
# |    fps              | 1145     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 123482   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.107    |
# |    n_updates        | 30845    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2692     |
# |    fps              | 1148     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 123971   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00112  |
# |    n_updates        | 30967    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 136      |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2696     |
# |    fps              | 1150     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 124450   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0055   |
# |    n_updates        | 31087    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 135      |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2700     |
# |    fps              | 1153     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 124959   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0219   |
# |    n_updates        | 31214    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2704     |
# |    fps              | 1154     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 125434   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00912  |
# |    n_updates        | 31333    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 133      |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2708     |
# |    fps              | 1149     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 125920   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.134    |
# |    n_updates        | 31454    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 131      |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2712     |
# |    fps              | 1149     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 126382   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00513  |
# |    n_updates        | 31570    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 130      |
# |    ep_rew_mean      | 130      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2716     |
# |    fps              | 1150     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 126858   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0616   |
# |    n_updates        | 31689    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 130      |
# |    ep_rew_mean      | 130      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2720     |
# |    fps              | 1149     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 127338   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00897  |
# |    n_updates        | 31809    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 129      |
# |    ep_rew_mean      | 129      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2724     |
# |    fps              | 1148     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 127805   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0036   |
# |    n_updates        | 31926    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 128      |
# |    ep_rew_mean      | 128      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2728     |
# |    fps              | 1149     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 128288   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0336   |
# |    n_updates        | 32046    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 127      |
# |    ep_rew_mean      | 127      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2732     |
# |    fps              | 1148     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 128736   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0218   |
# |    n_updates        | 32158    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 126      |
# |    ep_rew_mean      | 126      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2736     |
# |    fps              | 1149     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 129209   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00329  |
# |    n_updates        | 32277    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 125      |
# |    ep_rew_mean      | 125      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2740     |
# |    fps              | 1150     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 129679   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0522   |
# |    n_updates        | 32394    |
# ----------------------------------
# Average reward over 100 episodes: 500.00
# Target performance reached!

# %%
n_eval_episodes = 100
episode_rewards = []

for i in range(n_eval_episodes):
    render_mode = "human" if i == n_eval_episodes - 1 else None
    eval_env = gym.make("CartPole-v1", render_mode=render_mode)

    obs, _ = eval_env.reset()
    done = False
    total_reward = 0

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, _ = eval_env.step(action)
        total_reward += reward
        done = terminated or truncated

    episode_rewards.append(total_reward)
    eval_env.close()

# Show evaluation stats
print(f"Ran {n_eval_episodes} test episodes.")
print(f"Mean reward: {np.mean(episode_rewards):.2f}")
print(f"Std reward:  {np.std(episode_rewards):.2f}")
print(f"Min reward:  {np.min(episode_rewards):.2f}")
print(f"Max reward:  {np.max(episode_rewards):.2f}")
# Out:
# Ran 100 test episodes.
# Mean reward: 500.00
# Std reward:  0.00
# Min reward:  500.00
# Max reward:  500.00
